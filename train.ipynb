# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CDPWhnBNBUHtjJGrhgAJ")
project = rf.workspace("duonghungs-workspace").project("phan_loai_trai_cay-0tshd")
version = project.version(1)
dataset = version.download("yolov12")
# Out:
# ...
#   Using cached roboflow-1.3.10-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached pi_heif-1.4.0-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# ...
#   Using cached pillow_avif_plugin-1.5.5-cp313-cp313-win_amd64.whl.metadata (2.3 kB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# ...
# Using cached roboflow-1.3.10-py3-none-any.whl (250 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached pi_heif-1.4.0-cp313-cp313-win_amd64.whl (2.4 MB)
# Using cached pillow_avif_plugin-1.5.5-cp313-cp313-win_amd64.whl (9.9 MB)
# Using cached typer-0.25.1-py3-none-any.whl (58 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# ...
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# ...
#
# ...

# %%
from ultralytics import YOLO

# Nạp mô hình gốc YOLOv12 nano siêu nhẹ
model = YOLO('yolo12n.pt')

# Tiến hành huấn luyện
results = model.train(
    data=f"{dataset.location}/data.yaml", 
    epochs=50, 
    imgsz=640, 
    device='cpu'  # Ép chạy bằng CPU để không bị lỗi driver card màn hình
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from ultralytics import YOLO
#       3 # Nạp mô hình gốc YOLOv12 nano siêu nhẹ
#       4 model = YOLO('yolo12n.pt')
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
# !pip install ultralytics roboflow
# Out:
# ...
#   Using cached ultralytics-8.4.67-py3-none-any.whl.metadata (41 kB)
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached torch-2.12.0-cp313-cp313-win_amd64.whl.metadata (31 kB)
# ...
#   Using cached torchvision-0.27.0-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached polars-1.41.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached nvidia_ml_py-13.610.43-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached polars_runtime_32-1.41.2-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# ...
# Using cached ultralytics-8.4.67-py3-none-any.whl (1.3 MB)
# Using cached nvidia_ml_py-13.610.43-py3-none-any.whl (53 kB)
# Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
# Using cached polars-1.41.2-py3-none-any.whl (833 kB)
# Using cached polars_runtime_32-1.41.2-cp310-abi3-win_amd64.whl (52.0 MB)
# Using cached torch-2.12.0-cp313-cp313-win_amd64.whl (123.0 MB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CDPWhnBNBUHtjJGrhgAJ")
project = rf.workspace("duonghungs-workspace").project("phan_loai_trai_cay-0tshd")
version = project.version(6)
dataset = version.download("yolov12")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Phan_loai_trai_cay-6 in yolov12:: 100%|██████████| 139/139 [00:00<00:00, 2164.33it/s]

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"  # Chống sập Kernel Windows

from ultralytics import YOLO

# Sửa thành yolo12n.pt (bỏ chữ v) và thêm đường dẫn tuyệt đối chuẩn xác
model = YOLO("D:/training/yolo12n.pt")

# Tiến hành huấn luyện
results = model.train(
    data="D:/training/Phan_loai_trai_cay-6/data.yaml", 
    epochs=200, 
    imgsz=640, 
    device='cpu'
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.68 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.67  Python-3.13.5 torch-2.12.0+cpu CPU (13th Gen Intel Core i7-13650HX)
# ...
